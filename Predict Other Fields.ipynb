# %% [markdown]
# # Imports

# %%
import pandas as pd
import itertools
import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.preprocessing import text, sequence
from keras import utils
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Data Set Prep

# %%
df_requests = pd.read_excel('frc_data.xlsx', sheet_name='frc data')
#df_requests_condensed = pd.read_excel('frc_data.xlsx', sheet_name='frc_condensed')
# df_people = pd.read_excel('FRC Data1.xlsx', sheet_name='Requestor')

# %%
df_requests['Category'].value_counts()
# Out:
# Process    4010
# Systems    1975
# Forms      1587
# Rate       1235
# Other       505
# Name: Category, dtype: int64

# %%
df_requests.head()
# Out:
#       ID Submission Date Resolution Date            FRC Owner  \
# 0  14632      2018-10-18      2018-10-18  Iannacone, Kristine
# 1  14631      2018-10-18             NaT       Osswald, Ernst
# 2  14630      2018-10-18             NaT         Ewing, Jamie
# 3  14629      2018-10-18             NaT         Ewing, Jamie
# 4  14628      2018-10-18             NaT  Iannacone, Kristine
#
#                                         Request          Requestor  \
# 0                         Account locked in TAP  Melaniphy,Kevin M
# 1  Can we add Tow & Labor to auto without PPTs?  Loquiao,Jeffrey E
# 2          BPP rates higher than Property rates      Williams,Gina
# 3               Problem saving files to EPC/DMF  Albright,Kevin T.
# 4    Need point of contact for WC claims issues   Sterling,Heather
#
#                                  Request Description  Status Urgent? Reopen?  \
# 0  \n​\nTeam,\n \nMy policy is locked in TAP, can...  Closed      No      No
# 1  \n​\nHello,\n \nCan you please confirm if we a...    Open      No      No
# 2  \n​\nHello,\n \nCan you look into why the BPP ...    Open      No      No
# 3  \n​I thought I read something recently on this...    Open      No      No
# 4  \n​\nHello,\n \nI have a insured who would lik...    Open      No      No
#
#           ...         Incident / PME / Project # (Where Appl.)  \
# 0         ...                                              NaN
# 1         ...                                              NaN
# 2         ...                                              NaN
# 3         ...                                              NaN
# 4         ...                                              NaN
#
#               Created          Created By            Modified  \
# 0 2018-10-18 16:46:51  Iannacone,Kristine 2018-10-18 17:02:04
# 1 2018-10-18 16:42:54  Iannacone,Kristine 2018-10-18 16:42:54
# 2 2018-10-18 16:32:44  Iannacone,Kristine 2018-10-18 16:32:44
# 3 2018-10-18 16:25:37  Iannacone,Kristine 2018-10-18 16:25:37
# 4 2018-10-18 16:16:11  Iannacone,Kristine 2018-10-18 16:16:11
#
#      Last Modified By Submission Month           res date  \
# 0  Iannacone,Kristine           201810  10/18/2018  17:02
# 1  Iannacone,Kristine           201810                  -
# 2  Iannacone,Kristine           201810                  -
# 3  Iannacone,Kristine           201810                  -
# 4  Iannacone,Kristine           201810                  -
#
#                                       Comments/Notes Item Type  \
# 0  \nGood afternoon Kevin,\nThe TAP helpdesk will...      Item
# 1                                                NaN      Item
# 2                                                NaN      Item
# 3                                                NaN      Item
# 4                                                NaN      Item
#
#                  Path
# 0  ccm/FRC/Lists/TEST
# 1  ccm/FRC/Lists/TEST
# 2  ccm/FRC/Lists/TEST
# 3  ccm/FRC/Lists/TEST
# 4  ccm/FRC/Lists/TEST
#
# [5 rows x 33 columns]

# %%
df_requests['Clean Description'] = df_requests['Request Description'].str.replace('\n', '')

# %%
list(df_requests)
# Out:
# ['ID',
#  'Submission Date',
#  'Resolution Date',
#  'FRC Owner',
#  'Request',
#  'Requestor',
#  'Request Description',
#  'Status',
#  'Urgent?',
#  'Reopen?',
#  'Branch',
#  'Zone',
#  'Account/Policy # (Where Appl.)',
#  'Effective Date (Where Appl.)',
#  'Channel',
#  'Category',
#  'System',
#  'Key Word Roll-Up',
#  'LOB',
#  'Segment',
#  'Business Unit',
#  'FRC Assist',
#  'Resource(s) Used / Referred To',
#  'Incident / PME / Project # (Where Appl.)',
#  'Created',
#  'Created By',
#  'Modified',
#  'Last Modified By',
#  'Submission Month',
#  'res date',
#  'Comments/Notes',
#  'Item Type',
#  'Path',
#  'Clean Description',
#  'Updated LOB',
#  'key_words']

# %% [markdown]
# ## Condense LOB Categories

# %%
monoline_list = ['Equipment Breakdown', 'Inland Marine', 'International', 'Ocean Marine']
package_general_liability_list = ['Connect CNP', 'General Liability', 'Multiline']
package_property_list = ['Paramount Package', 'Property']
condensed_lob_list = []
for row in df_requests['LOB']:
    if row in monoline_list:
        condensed_lob_list.append('Monoline')
    elif row in package_general_liability_list:
        condensed_lob_list.append('Package General Liability')
    elif row in package_property_list:
        condensed_lob_list.append('Package Property')
    else:
        condensed_lob_list.append(row)
        
df_requests['Updated LOB'] = condensed_lob_list

# %%
df_requests['Updated LOB'].value_counts()
# Out:
# Package General Liability    2407
# Auto                         1948
# Workers Comp                 1665
# Package Property             1438
# Umbrella                      878
# Not LOB Specific              561
# Monoline                      416
# Name: Updated LOB, dtype: int64

# %% [markdown]
# ### Test Classification without RST Help

# %%
# df_condensed = df_requests.drop(df_requests[df_requests.Channel == 'RST Help'].index)

# monoline_list = ['Equipment Breakdown', 'Inland Marine', 'International', 'Ocean Marine']
# package_general_liability_list = ['Connect CNP', 'General Liability', 'Multiline']
# package_property_list = ['Paramount Package', 'Property']
# condensed_lob_list = []
# for row in df_condensed['LOB']:
#     if row in monoline_list:
#         condensed_lob_list.append('Monoline')
#     elif row in package_general_liability_list:
#         condensed_lob_list.append('Package General Liability')
#     elif row in package_property_list:
#         condensed_lob_list.append('Package Property')
#     else:
#         condensed_lob_list.append(row)
# df_condensed['Updated LOB'] = condensed_lob_list

# %% [markdown]
# ## Reduce Keywords

# %%
key_word_list = ['Rate Change',
'Form Review',
'Endorsement Print',
'Premium Discrepancy',
'CAT',
'Endorsement Process',
'Experience Modification',
'Billing',
'System Issue']
condensed_list = []
for row in df_requests['Key Word Roll-Up']:
    if row in key_word_list:
        condensed_list.append(row)
    else: 
        condensed_list.append('Other')
        
df_requests['key_words'] = condensed_list

# %% [markdown]
# ## Keras Text Classification - LOB

# %%
train_size = int(len(df_requests) * .8)
train_posts = df_requests['Request Description'][:train_size]
train_tags = df_requests['System'][:train_size]
test_posts = df_requests['Request Description'][train_size:]
test_tags = df_requests['System'][train_size:]

vocab_size = 1000
tokenize = text.Tokenizer(num_words=vocab_size)
tokenize.fit_on_texts(train_posts)

x_train = tokenize.texts_to_matrix(train_posts)

encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

model = Sequential()

model.add(Dense(512, input_shape=(vocab_size,)))
model.add(Activation('relu'))

model.add(Dense(y_train.shape[1]))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

history = model.fit(x_train, y_train, 
                    batch_size=100, 
                    epochs=2, 
                    verbose=1, 
                    validation_split=0.1)
# Out:
# Train on 6705 samples, validate on 745 samples
# Epoch 1/2
# 6705/6705 [==============================] - 9s 1ms/step - loss: 1.9146 - acc: 0.4808 - val_loss: 1.7211 - val_acc: 0.5020
# Epoch 2/2
# 6705/6705 [==============================] - 9s 1ms/step - loss: 1.2957 - acc: 0.6073 - val_loss: 1.5381 - val_acc: 0.5329

# %%
predictions = model.predict(x_train)
np.argmax(predictions[0])
# Out:
# 0

# %%
predicted_labels = [np.argmax(x) for x in predictions]
predicted_labels
# Out:
# [0,
#  0,
#  4,
#  4,
#  6,
#  6,
#  6,
#  0,
#  3,
#  0,
#  5,
#  3,
#  2,
#  6,
#  6,
#  2,
#  4,
#  0,
#  0,
#  0,
#  5,
#  0,
#  6,
#  0,
#  6,
#  2,
#  0,
#  4,
#  3,
#  3,
#  5,
#  0,
#  6,
#  0,
#  5,
#  5,
#  3,
#  0,
#  0,
#  1,
#  4,
#  0,
#  2,
#  5,
#  2,
#  0,
#  0,
#  3,
#  6,
#  0,
#  2,
#  0,
#  3,
#  0,
#  6,
#  0,
#  5,
#  5,
#  0,
#  3,
#  5,
#  6,
#  1,
#  5,
#  6,
#  3,
#  0,
#  0,
#  3,
#  6,
#  6,
#  6,
#  3,
#  6,
#  6,
#  0,
#  6,
#  0,
#  6,
#  2,
#  3,
#  1,
#  2,
#  0,
#  0,
#  3,
#  0,
#  0,
#  0,
#  6,
#  0,
#  3,
#  2,
#  0,
#  3,
#  0,
#  3,
#  6,
#  6,
#  0,
#  4,
#  3,
#  6,
#  5,
#  0,
#  5,
#  0,
#  2,
#  5,
#  3,
#  6,
#  3,
#  0,
#  4,
#  0,
#  6,
#  4,
#  3,
#  3,
#  0,
#  2,
#  3,
#  3,
#  6,
#  0,
#  4,
#  5,
#  6,
#  6,
#  3,
#  0,
#  3,
#  0,
#  0,
#  0,
#  4,
#  3,
#  4,
#  4,
#  6,
#  0,
#  0,
#  5,
#  4,
#  4,
#  3,
#  5,
#  3,
#  3,
#  0,
#  2,
#  0,
#  3,
#  3,
#  0,
#  0,
#  0,
#  0,
#  0,
#  4,
#  3,
#  0,
#  3,
#  0,
#  0,
#  3,
#  0,
#  0,
#  0,
#  3,
#  0,
#  0,
#  0,
#  6,
#  0,
#  4,
#  3,
#  2,
#  0,
#  0,
#  3,
#  2,
#  0,
#  6,
#  4,
#  3,
#  3,
#  6,
#  3,
#  6,
#  3,
#  0,
#  6,
#  2,
#  3,
#  4,
#  0,
#  1,
#  4,
#  0,
#  4,
#  6,
#  6,
#  2,
#  0,
#  0,
#  2,
#  0,
#  5,
#  3,
#  3,
#  6,
#  0,
#  3,
#  3,
#  0,
#  0,
#  6,
#  0,
#  0,
#  3,
#  3,
#  4,
#  4,
#  6,
#  3,
#  0,
#  0,
#  0,
#  5,
#  6,
#  4,
#  4,
#  6,
#  3,
#  6,
#  0,
#  3,
#  0,
#  3,
#  3,
#  0,
#  0,
#  4,
#  3,
#  4,
#  3,
#  0,
#  6,
#  0,
#  3,
#  4,
#  5,
#  3,
#  6,
#  0,
#  0,
#  3,
#  3,
#  6,
#  0,
#  4,
#  0,
#  0,
#  0,
#  0,
#  0,
#  4,
#  0,
#  4,
#  6,
#  6,
#  6,
#  0,
#  3,
#  0,
#  3,
#  0,
#  0,
#  3,
#  6,
#  0,
#  4,
#  0,
#  0,
#  0,
#  6,
#  3,
#  4,
#  2,
#  4,
#  0,
#  6,
#  0,
#  3,
#  0,
#  4,
#  3,
#  6,
#  4,
#  0,
#  0,
#  3,
#  0,
#  0,
#  4,
#  3,
#  6,
#  6,
#  6,
#  3,
#  2,
#  0,
#  0,
#  3,
#  0,
#  1,
#  0,
#  4,
#  0,
#  0,
#  3,
#  4,
#  5,
#  0,
#  3,
#  6,
#  0,
#  3,
#  0,
#  3,
#  5,
#  4,
#  0,
#  3,
#  3,
#  0,
#  3,
#  3,
#  4,
#  0,
#  0,
#  4,
#  5,
#  0,
#  3,
#  4,
#  6,
#  0,
#  0,
#  3,
#  0,
#  4,
#  0,
#  4,
#  2,
#  0,
#  6,
#  0,
#  4,
#  4,
#  6,
#  0,
#  0,
#  0,
#  4,
#  3,
#  3,
#  0,
#  2,
#  4,
#  4,
#  0,
#  3,
#  3,
#  0,
#  3,
#  2,
#  4,
#  4,
#  0,
#  6,
#  0,
#  3,
#  6,
#  6,
#  6,
#  4,
#  4,
#  0,
#  4,
#  6,
#  0,
#  3,
#  6,
#  0,
#  3,
#  0,
#  5,
#  3,
#  3,
#  6,
#  2,
#  6,
#  0,
#  0,
#  5,
#  1,
#  2,
#  0,
#  3,
#  0,
#  0,
#  3,
#  6,
#  2,
#  3,
#  0,
#  0,
#  3,
#  0,
#  4,
#  6,
#  3,
#  0,
#  4,
#  4,
#  4,
#  4,
#  0,
#  6,
#  4,
#  6,
#  6,
#  3,
#  6,
#  3,
#  6,
#  0,
#  2,
#  2,
#  0,
#  3,
#  6,
#  4,
#  0,
#  4,
#  0,
#  2,
#  6,
#  6,
#  4,
#  0,
#  3,
#  6,
#  4,
#  3,
#  0,
#  3,
#  3,
#  6,
#  6,
#  0,
#  0,
#  3,
#  6,
#  4,
#  3,
#  2,
#  0,
#  0,
#  6,
#  4,
#  3,
#  0,
#  6,
#  4,
#  2,
#  3,
#  0,
#  1,
#  6,
#  6,
#  0,
#  4,
#  0,
#  5,
#  3,
#  6,
#  0,
#  3,
#  6,
#  6,
#  6,
#  3,
#  6,
#  0,
#  5,
#  3,
#  3,
#  3,
#  0,
#  0,
#  6,
#  4,
#  0,
#  5,
#  0,
#  6,
#  0,
#  0,
#  2,
#  6,
#  3,
#  6,
#  4,
#  3,
#  0,
#  0,
#  3,
#  0,
#  3,
#  1,
#  0,
#  0,
#  4,
#  0,
#  6,
#  3,
#  2,
#  6,
#  5,
#  3,
#  3,
#  5,
#  5,
#  6,
#  4,
#  0,
#  0,
#  4,
#  3,
#  5,
#  0,
#  5,
#  2,
#  6,
#  0,
#  6,
#  6,
#  0,
#  6,
#  0,
#  3,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  6,
#  5,
#  6,
#  3,
#  3,
#  3,
#  6,
#  0,
#  6,
#  6,
#  6,
#  3,
#  0,
#  3,
#  6,
#  0,
#  4,
#  2,
#  5,
#  1,
#  0,
#  0,
#  0,
#  4,
#  6,
#  6,
#  0,
#  0,
#  3,
#  4,
#  0,
#  6,
#  0,
#  6,
#  4,
#  0,
#  3,
#  6,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  6,
#  5,
#  3,
#  5,
#  4,
#  0,
#  6,
#  4,
#  2,
#  4,
#  4,
#  0,
#  4,
#  6,
#  3,
#  0,
#  0,
#  3,
#  0,
#  3,
#  0,
#  6,
#  2,
#  0,
#  2,
#  6,
#  3,
#  4,
#  3,
#  6,
#  3,
#  3,
#  0,
#  4,
#  3,
#  0,
#  6,
#  0,
#  3,
#  4,
#  5,
#  0,
#  0,
#  2,
#  3,
#  6,
#  3,
#  4,
#  6,
#  3,
#  3,
#  5,
#  4,
#  0,
#  0,
#  3,
#  4,
#  2,
#  3,
#  3,
#  6,
#  0,
#  2,
#  4,
#  4,
#  3,
#  2,
#  3,
#  2,
#  5,
#  2,
#  2,
#  0,
#  6,
#  5,
#  6,
#  1,
#  0,
#  6,
#  3,
#  6,
#  3,
#  0,
#  3,
#  3,
#  6,
#  4,
#  3,
#  5,
#  0,
#  3,
#  0,
#  2,
#  0,
#  1,
#  0,
#  5,
#  6,
#  4,
#  0,
#  3,
#  3,
#  3,
#  0,
#  3,
#  6,
#  3,
#  0,
#  0,
#  6,
#  0,
#  1,
#  0,
#  1,
#  4,
#  0,
#  0,
#  0,
#  3,
#  0,
#  3,
#  4,
#  3,
#  2,
#  0,
#  0,
#  3,
#  4,
#  0,
#  6,
#  0,
#  4,
#  4,
#  4,
#  2,
#  0,
#  3,
#  6,
#  5,
#  0,
#  0,
#  2,
#  0,
#  5,
#  3,
#  3,
#  4,
#  2,
#  5,
#  4,
#  3,
#  4,
#  0,
#  3,
#  0,
#  6,
#  6,
#  0,
#  5,
#  3,
#  0,
#  0,
#  2,
#  1,
#  6,
#  2,
#  5,
#  5,
#  4,
#  2,
#  4,
#  3,
#  0,
#  0,
#  6,
#  0,
#  0,
#  6,
#  6,
#  0,
#  4,
#  0,
#  0,
#  6,
#  5,
#  3,
#  4,
#  4,
#  0,
#  3,
#  3,
#  3,
#  6,
#  5,
#  0,
#  0,
#  6,
#  0,
#  3,
#  0,
#  0,
#  3,
#  0,
#  0,
#  0,
#  0,
#  0,
#  6,
#  6,
#  0,
#  0,
#  3,
#  0,
#  4,
#  3,
#  3,
#  2,
#  3,
#  0,
#  3,
#  0,
#  4,
#  0,
#  4,
#  3,
#  3,
#  6,
#  4,
#  2,
#  4,
#  3,
#  4,
#  6,
#  3,
#  0,
#  3,
#  0,
#  5,
#  0,
#  3,
#  5,
#  4,
#  3,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  4,
#  2,
#  5,
#  0,
#  0,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  4,
#  4,
#  6,
#  4,
#  6,
#  0,
#  0,
#  3,
#  3,
#  0,
#  4,
#  6,
#  3,
#  0,
#  0,
#  6,
#  2,
#  2,
#  6,
#  3,
#  4,
#  5,
#  0,
#  1,
#  3,
#  3,
#  3,
#  6,
#  2,
#  0,
#  3,
#  3,
#  0,
#  6,
#  0,
#  3,
#  0,
#  0,
#  3,
#  6,
#  0,
#  4,
#  0,
#  0,
#  0,
#  3,
#  0,
#  6,
#  4,
#  3,
#  4,
#  0,
#  0,
#  3,
#  6,
#  3,
#  3,
#  0,
#  5,
#  3,
#  0,
#  3,
#  4,
#  6,
#  0,
#  6,
#  6,
#  0,
#  5,
#  2,
#  4,
#  6,
#  0,
#  2,
#  6,
#  6,
#  0,
#  3,
#  4,
#  4,
#  2,
#  4,
#  1,
#  0,
#  6,
#  3,
#  4,
#  6,
#  0,
#  5,
#  4,
#  3,
#  5,
#  2,
#  3,
#  0,
#  0,
#  0,
#  0,
#  6,
#  3,
#  3,
#  0,
#  3,
#  3,
#  0,
#  3,
#  4,
#  6,
#  5,
#  3,
#  0,
#  2,
#  6,
#  4,
#  0,
#  0,
#  0,
#  4,
#  0,
#  5,
#  6,
#  3,
#  3,
#  5,
#  3,
#  6,
#  0,
#  0,
#  6,
#  6,
#  6,
#  3,
#  6,
#  ...]

# %%
y_labels = [np.argmax(x) for x in y_train]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_labels, predicted_labels)
# Out:
# array([[1498,    0,   19,   63,   20,    4,   26],
#        [  38,  137,   12,   44,   47,    2,   17],
#        [  94,    0,  287,   96,   20,    8,   36],
#        [ 242,    0,   63, 1329,  107,   26,   68],
#        [ 104,    1,   17,  148,  876,    6,   23],
#        [ 100,    0,   16,   59,   23,  420,   31],
#        [ 144,    1,   16,   69,   20,    6, 1067]])

# %% [markdown]
# ## Keras text classification - Request

# %%
train_size = int(len(df_requests) * .8)
train_posts = df_requests['Request'][:train_size]
train_tags = df_requests['Updated LOB'][:train_size]
test_posts = df_requests['Request'][train_size:]
test_tags = df_requests['Updated LOB'][train_size:]

vocab_size = 1000
tokenize = text.Tokenizer(num_words=vocab_size)
tokenize.fit_on_texts(train_posts)

x_train = tokenize.texts_to_matrix(train_posts)

encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

model = Sequential()

model.add(Dense(512, input_shape=(vocab_size,)))
model.add(Activation('relu'))

model.add(Dense(y_train.shape[1]))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

history = model.fit(x_train, y_train, 
                    batch_size=100, 
                    epochs=2, 
                    verbose=1, 
                    validation_split=0.1)
# Out:
# Train on 6705 samples, validate on 745 samples
# Epoch 1/2
# 6705/6705 [==============================] - 9s 1ms/step - loss: 1.5965 - acc: 0.4710 - val_loss: 1.4002 - val_acc: 0.5315
# Epoch 2/2
# 6705/6705 [==============================] - 8s 1ms/step - loss: 1.0624 - acc: 0.6513 - val_loss: 1.1424 - val_acc: 0.5893

# %% [markdown]
# ## N Grams - LOB

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
sw = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/ZGS/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# vectorizer = CountVectorizer(stop_words=sw,ngram_range=(1,2))
# train_posts = vectorizer.fit_transform(df_requests['Request Description'])
# train_posts.shape

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(stop_words=sw,ngram_range=(1,4))
train_posts = vectorizer.fit_transform(df_requests['Clean Description'].values.astype('U'))
train_posts.shape
#x = v.fit_transform(df['Review'].values.astype('U'))
# Out:
# (9313, 601816)

# %%
#
train_size = int(len(df_requests) * .8)
# train_posts = df_request['Request Description']#[:train_size]
# train_tags = df_requests['Updated LOB']#[:train_size]
# test_posts = df_requests['Request Description']#[train_size:]
# test_tags = df_requests['Updated LOB']#[train_size:]
# train_tags.shape

# %%
train_size = int(len(df_requests) * .8)
train_posts = df_requests['Clean Description']#[:train_size]
train_tags = df_requests['Updated LOB']#[:train_size]
test_posts = df_requests['Clean Description']#[train_size:]
test_tags = df_requests['Updated LOB']#[train_size:]
train_tags.shape
# Out:
# (9313,)

# %%
vocab_size = 8000
tokenize = text.Tokenizer(num_words=vocab_size)
tokenize.fit_on_texts(train_posts)

x_train = tokenize.texts_to_matrix(train_posts)
#print(x_train.shape)

print(x_train[0])
encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)
#y_train.shape

model = Sequential()
model.add(Dense(256, input_shape=(x_train.shape[1],)))
#model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(y_train.shape[1]))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

history = model.fit(x_train, y_train, 
                    batch_size=100, 
                    epochs=3, 
                    verbose=1, 
                    validation_split=0.1)
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# Train on 8381 samples, validate on 932 samples
# Epoch 1/3
# 8381/8381 [==============================] - 39s 5ms/step - loss: 1.4142 - acc: 0.5174 - val_loss: 1.1170 - val_acc: 0.6277
# Epoch 2/3
# 8381/8381 [==============================] - 38s 5ms/step - loss: 0.7165 - acc: 0.7834 - val_loss: 1.0601 - val_acc: 0.6234
# Epoch 3/3
# 8381/8381 [==============================] - 41s 5ms/step - loss: 0.4498 - acc: 0.8689 - val_loss: 1.0601 - val_acc: 0.6277

# %%
df_requests.head()
# Out:
#       ID Submission Date Resolution Date            FRC Owner  \
# 0  14632      2018-10-18      2018-10-18  Iannacone, Kristine
# 1  14631      2018-10-18             NaT       Osswald, Ernst
# 2  14630      2018-10-18             NaT         Ewing, Jamie
# 3  14629      2018-10-18             NaT         Ewing, Jamie
# 4  14628      2018-10-18             NaT  Iannacone, Kristine
#
#                                         Request          Requestor  \
# 0                         Account locked in TAP  Melaniphy,Kevin M
# 1  Can we add Tow & Labor to auto without PPTs?  Loquiao,Jeffrey E
# 2          BPP rates higher than Property rates      Williams,Gina
# 3               Problem saving files to EPC/DMF  Albright,Kevin T.
# 4    Need point of contact for WC claims issues   Sterling,Heather
#
#                                  Request Description  Status Urgent? Reopen?  \
# 0  \n​\nTeam,\n \nMy policy is locked in TAP, can...  Closed      No      No
# 1  \n​\nHello,\n \nCan you please confirm if we a...    Open      No      No
# 2  \n​\nHello,\n \nCan you look into why the BPP ...    Open      No      No
# 3  \n​I thought I read something recently on this...    Open      No      No
# 4  \n​\nHello,\n \nI have a insured who would lik...    Open      No      No
#
#          ...                    Created          Created By  \
# 0        ...        2018-10-18 16:46:51  Iannacone,Kristine
# 1        ...        2018-10-18 16:42:54  Iannacone,Kristine
# 2        ...        2018-10-18 16:32:44  Iannacone,Kristine
# 3        ...        2018-10-18 16:25:37  Iannacone,Kristine
# 4        ...        2018-10-18 16:16:11  Iannacone,Kristine
#
#              Modified    Last Modified By Submission Month           res date  \
# 0 2018-10-18 17:02:04  Iannacone,Kristine           201810  10/18/2018  17:02
# 1 2018-10-18 16:42:54  Iannacone,Kristine           201810                  -
# 2 2018-10-18 16:32:44  Iannacone,Kristine           201810                  -
# 3 2018-10-18 16:25:37  Iannacone,Kristine           201810                  -
# 4 2018-10-18 16:16:11  Iannacone,Kristine           201810                  -
#
#                                       Comments/Notes Item Type  \
# 0  \nGood afternoon Kevin,\nThe TAP helpdesk will...      Item
# 1                                                NaN      Item
# 2                                                NaN      Item
# 3                                                NaN      Item
# 4                                                NaN      Item
#
#                  Path       Updated LOB
# 0  ccm/FRC/Lists/TEST  Not LOB Specific
# 1  ccm/FRC/Lists/TEST              Auto
# 2  ccm/FRC/Lists/TEST  Package Property
# 3  ccm/FRC/Lists/TEST  Package Property
# 4  ccm/FRC/Lists/TEST      Workers Comp
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Export to Excel

# %%
writer = pd.ExcelWriter('categories_output.xlsx')
df_list.to_excel(writer,'Sheet1')
writer.save()

# %%
df_requests['Updated LOB'].value_counts()
# Out:
# Package General Liability    2407
# Auto                         1948
# Workers Comp                 1665
# Package Property             1438
# Umbrella                      878
# Not LOB Specific              561
# Monoline                      416
# Name: Updated LOB, dtype: int64

# %%
fast_text = []
for row in df_requests['Updated LOB']:
    if row == 'Package General Liability':
        #fast_text.append('__label__Package-General-Liability')
        fast_text.append('__label__Package-General-Liability')
    elif row == 'Auto':
        fast_text.append('__label__Auto')
    elif row == 'Workers Comp':
        fast_text.append('__label__Workers-Comp')
    elif row =='Package Property':
        fast_text.append('__label__Package-Property')
    elif row == 'Umbrella':
        fast_text.append('__label__Umbrella')
    elif row == 'Not LOB Specific':
        fast_text.append('__label__Not-LOB-Specific')
    else:
        fast_text.append('__label__Monoline')

# %%
fast_text
# Out:
# ['__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Package-Property',
#  '__label__Package-Property',
#  '__label__Workers-Comp',
#  '__label__Workers-Comp',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__

#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Umbrella',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Umbrella',
#  '__label__Auto',
#  '__label__Auto',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Umbrella',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Not-LOB-Specific',
#  '__label__Package-Property',
#  '__label__Package-Property',
#  '__label__Not-LOB-Specific',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Not-LOB-Specific',
#  '__label__Umbrella',
#  '__label__Not-LOB-Specific',
#  '__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Umbrella',
#  '__label__Workers-Comp',
#  '__label__Monoline',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Not-LOB-Specific',
#  '__label__Workers-Comp',
#  '__label__Not-LOB-Specific',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Umbrella',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Not-LOB-Specific',
#  '__label__Monoline',
#  '__label__Auto',
#  '__label__Umbrella',
#  '__label__Package-Property',
#  '__label__Package-Property',
#  '__label__Not-LOB-Specific',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Monoline',
#  '__label__Package-General-Liability',
#  '__label__Monoline',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Umbrella',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Package-Property',
#  '__label__Package-Property',
#  '__label__Package-Property',
#  '__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Umbrella',
#  '__label__Auto',
#  '__label__Auto',
#  '__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Umbrella',
#  '__label__Package-Property',
#  '__label__Monoline',
#  '__label__Package-General-Liability',
#  '__label__Not-LOB-Specific',
#  '__label__Umbrella',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Workers-Comp',
#  '__label__Workers-Comp',
#  '__label__Umbrella',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__
#  '__label__Not-LOB-Specific',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Umbrella',
#  '__label__Auto',
#  '__label__Monoline',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Umbrella',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Not-LOB-Specific',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Umbrella',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Workers-Comp',
#  '__label__Umbrella',
#  '__label__Workers-Comp',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Umbrella',
#  '__label__Not-LOB-Specific',
#  '__label__Package-Property',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Package-Property',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Monoline',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Auto',
#  '__label__Umbrella',
#  '__label__Package-Property',
#  '__label__Monoline',
#  '__label__Umbrella',
#  '__label__Not-LOB-Specific',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Package-Property',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Package-General-Liability',
#  '__label__Not-LOB-Specific',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Not-LOB-Specific',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Auto',
#  '__label__Auto',
#  '__label__Not-LOB-Specific',
#  '__label__Auto',
#  '__label__Umbrella',
#  '__label__Umbrella',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Package-General-Liability',
#  '__label__Umbrella',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  '__label__Auto',
#  '__label__Auto',
#  '__label__Workers-Comp',
#  '__label__Workers-Comp',
#  '__label__Workers-Comp',
#  '__label__Package-General-Liability',
#  '__label__Workers-Comp',
#  ...]

# %%
df_requests['Fast_Text'] = fast_text

# %%
# description_text = df_requests['Request Description'].tolist()
# final_text = []
# for row in df_requests['Fast_Text']:
#     final_text.append('{} {}'.format(final_text, description_text))

# %%
df_requests['Combined Text'] = df_requests[['Fast_Text', 'Clean Description']].apply(lambda x: ' '.join(x), axis=1)

# %%
df_requests.head()
# Out:
#       ID Submission Date Resolution Date            FRC Owner  \
# 0  14632      2018-10-18      2018-10-18  Iannacone, Kristine
# 1  14631      2018-10-18             NaT       Osswald, Ernst
# 2  14630      2018-10-18             NaT         Ewing, Jamie
# 3  14629      2018-10-18             NaT         Ewing, Jamie
# 4  14628      2018-10-18             NaT  Iannacone, Kristine
#
#                                         Request          Requestor  \
# 0                         Account locked in TAP  Melaniphy,Kevin M
# 1  Can we add Tow & Labor to auto without PPTs?  Loquiao,Jeffrey E
# 2          BPP rates higher than Property rates      Williams,Gina
# 3               Problem saving files to EPC/DMF  Albright,Kevin T.
# 4    Need point of contact for WC claims issues   Sterling,Heather
#
#                                  Request Description  Status Urgent? Reopen?  \
# 0  \n​\nTeam,\n \nMy policy is locked in TAP, can...  Closed      No      No
# 1  \n​\nHello,\n \nCan you please confirm if we a...    Open      No      No
# 2  \n​\nHello,\n \nCan you look into why the BPP ...    Open      No      No
# 3  \n​I thought I read something recently on this...    Open      No      No
# 4  \n​\nHello,\n \nI have a insured who would lik...    Open      No      No
#
#                          ...                            Last Modified By  \
# 0                        ...                          Iannacone,Kristine
# 1                        ...                          Iannacone,Kristine
# 2                        ...                          Iannacone,Kristine
# 3                        ...                          Iannacone,Kristine
# 4                        ...                          Iannacone,Kristine
#
#   Submission Month           res date  \
# 0           201810  10/18/2018  17:02
# 1           201810                  -
# 2           201810                  -
# 3           201810                  -
# 4           201810                  -
#
#                                       Comments/Notes Item Type  \
# 0  \nGood afternoon Kevin,\nThe TAP helpdesk will...      Item
# 1                                                NaN      Item
# 2                                                NaN      Item
# 3                                                NaN      Item
# 4                                                NaN      Item
#
#                  Path       Updated LOB                  Fast_Text  \
# 0  ccm/FRC/Lists/TEST  Not LOB Specific  __label__Not-LOB-Specific
# 1  ccm/FRC/Lists/TEST              Auto              __label__Auto
# 2  ccm/FRC/Lists/TEST  Package Property  __label__Package-Property
# 3  ccm/FRC/Lists/TEST  Package Property  __label__Package-Property
# 4  ccm/FRC/Lists/TEST      Workers Comp      __label__Workers-Comp
#
#                                        Combined Text  \
# 0  __label__Not-LOB-Specific ​Team, My policy is ...
# 1  __label__Auto ​Hello, Can you please confirm i...
# 2  __label__Package-Property ​Hello, Can you look...
# 3  __label__Package-Property ​I thought I read so...
# 4  __label__Workers-Comp ​Hello, I have a insured...
#
#                                    Clean Description
# 0  ​Team, My policy is locked in TAP, can you ple...
# 1  ​Hello, Can you please confirm if we are able ...
# 2  ​Hello, Can you look into why the BPP rates ar...
# 3  ​I thought I read something recently on this b...
# 4  ​Hello, I have a insured who would like to hav...
#
# [5 rows x 37 columns]

# %%
new_df['Combined Text'].str.replace('"', '').to_csv('combined_text.txt', sep='\t', index=False)

# %%
df_requests['Combined Text']
# Out:
# 0       __label__Not-LOB-Specific ​Team, My policy is ...
# 1       __label__Auto ​Hello, Can you please confirm i...
# 2       __label__Package-Property ​Hello, Can you look...
# 3       __label__Package-Property ​I thought I read so...
# 4       __label__Workers-Comp ​Hello, I have a insured...
# 5       __label__Workers-Comp Hi,Can you advise on the...
# 6       __label__Workers-Comp ​Is there a work around ...
# 7       __label__Auto ​Please see below question. Can ...
# 8       __label__Package-General-Liability ​I have a C...
# 9       __label__Auto ​Last year's auto PD experience ...
# 10      __label__Umbrella ​ Umbrella rate change looks...
# 11      __label__Package-General-Liability ​Hi there, ...
# 12      __label__Not-LOB-Specific ​Hi FRC team, I am h...
# 13      __label__Not-LOB-Specific ​Kyle had a question...
# 14      __label__Workers-Comp ​Hi! I have an agent ask...
# 15      __label__Not-LOB-Specific ​When will 10 equal ...
# 16      __label__Package-Property Working on renewal o...
# 17      __label__Auto ​Hi,We have a link to the PA UM/...
# 18      __label__Workers-Comp Answered by Ann MarieJan...
# 19      __label__Auto ​I've tried on several larger au...
# 20      __label__Package-Property ​Ann Marie, Are we a...
# 21      __label__Package-Property Hi Josh,Can you plea...
# 22      __label__Workers-Comp ​Hello Scott, The Name a...
# 23      __label__Auto ​The above policy number is a 10...
# 24      __label__Workers-Comp ​Hi Carol, We received t...
# 25      __label__Not-LOB-Specific ​I lost Google Earth...
# 26      __label__Auto ​Good Morning, Is there any way ...
# 27      __label__Package-Property ​ Why does the accou...
# 28      __label__Not-LOB-Specific Good morning,Please ...
# 29      __label__Package-General-Liability ​ Technical...
#                               ...
# 9283    __label__Package-General-Liability ​The broker...
# 9284    __label__Package-General-Liability ​Is there a...
# 9285    __label__Package-General-Liability Good mornin...
# 9286    __label__Package-General-Liability ​I am looki...
# 9287    __label__Package-General-Liability ​ I changed...
# 9288    __label__Auto Hey MikeI'm reviewing the Physic...
# 9289    __label__Umbrella ​Hi,The policy my UW and I a...
# 9290    __label__Workers-Comp Hello,  Please see below...
# 9291    __label__Workers-Comp ​Please process the atta...
# 9292    __label__Auto Is there any way you can speed u...
# 9293    __label__Package-General-Liability ​This was t...
# 9294    __label__Package-Property ​HI, I am reviewing ...
# 9295    __label__Package-General-Liability ​I also nee...
# 9296    __label__Auto Auto premium is incorrect, this ...
# 9297    __label__Auto ​Please contact me about sending...
# 9298    __label__Workers-Comp ​Hi there, Can we get so...
# 9299    __label__Umbrella ​I do not see my premium aft...
# 9300    __label__Umbrella ​The  UW approved adding a "...
# 9301    __label__Package-Property Tri3ed several times...
# 9302    __label__Workers-Comp ​Good morning-I am follo...
# 9303    __label__Package-Property ​CAT Model keeps fai...
# 9304    __label__Workers-Comp ​I received this communi...
# 9305    __label__Package-General-Liability ​I need BPM...
# 9306    __label__Workers-Comp ​Another CA Waiver mess ...
# 9307    __label__Auto ​Please forward at your earliest...
# 9308    __label__Not-LOB-Specific Good morning –  I fo...
# 9309    __label__Package-General-Liability ​Hi Karen, ...
# 9310    __label__Auto ​Can we use symbol 7 to activate...
# 9311    __label__Package-Property RST is showing loc 1...
# 9312    __label__Auto ​Good morning- I am sending this...
# Name: Combined Text, Length: 9313, dtype: object

# %%
['Clean Description'] = df_requests['Request Description'].str.replace('\n', '')

# %%
from sklearn.utils import shuffle
new_df = shuffle(df_requests)

# %%
new_df['Clean Description']
# Out:
# 1856    ​Curious.... Increased premium 8%; DFM increas...
# 5347    ​Team here is another one just due to time.  C...
# 3541    Today I watched the Commercial Auto EPC Traini...
# 1996    Do we have a version of the sexual abuse and m...
# 3256    ​On a GL Composite Rated policy (Paramount Pac...
# 7876    ​Please review this one, why did we add the of...
# 814     ​RE factors not available for WC policies - du...
# 3740                      ​how do I update my UW remarks?
# 2132    ​I've converted policy once this am with one c...
# 3733                    ​Please expedite so we can quote.
# 9150    How are BOR's handled? Is the "old agent" stil...
# 3487    ​I am trying to add additional loss informatio...
# 4569    ​I have an agent asking me for a W-9 for CNA.T...
# 4375    Please have the PMT policy corrected.  There w...
# 9057    ​Hello,I am part of Specialty's Underwriting S...
# 5847    Hi FRC team,Can you please help us investigate...
# 3524    Aon would like me to confirm my pricing on an ...
# 2033    ​Hi Mike – I am trying to get this article thr...
# 3796                              ​NCCI Inspection Report
# 7271    ​Good morning Kim/Karen, I was hoping to get s...
# 7397    ​Hello, We are getting a lot of questions on d...
# 3020    Good Afternoon All, Can someone from the suppo...
# 6691    See the questions that Aon is seeking response...
# 6601    ​Can we confirm property rate decrease is corr...
# 9155    ​Does the insured have to sign and return the ...
# 2969    ​Are we able to update the agent address – kee...
# 7715    Hello,I'm having an issue where it appears tha...
# 1034    ​Hello, I'm reaching out for assistance gettin...
# 6877    ​Sue asked for help with assigning.  She wante...
# 1427    ​Hi! Question, Just need clarification regardi...
#                               ...
# 3293    ​Good afternoon, Please see the below general ...
# 9021    ​Good afternoon, The broker on this account re...
# 5811    Field Resource Team-Please see below.  Can you...
# 7592    Hi Team,The following forms are not showing up...
# 4791    ​Hi, I am trying to figure out what this endor...
# 2812    Technical rating issue for CF policy(ies) 6072...
# 4884    ​ Message regarding technical rating error for...
# 68      ​This is for a Manufactuer's E & O policy and ...
# 3450    ​Team,  Can you assist with routing this to Le...
# 1751    ​Would you be able to tell me when the claim r...
# 713                               ​I cant seem to get on.
# 1385    ​Please see below activity that is assigned to...
# 2130    Hello,We have an account that we need to model...
# 7392    ​Good Afternoon Team, Could you please advise ...
# 414     ​Hello,I am unable to find a matching endorsem...
# 2981    ​Hello- Can you assist us with the WC NOC?  We...
# 8302    Hi FRC,I'm getting fishing emails constantly (...
# 3248    ​Can you please advise what the error is relat...
# 2346    ​I have noticed that several of my auto polici...
# 5246    ​This account is domiciled out of Florida.  Th...
# 3043    ​Can this be updated to reflect the first ques...
# 288     I keep getting the below error when trying to ...
# 3988    ​ each time I refresh I get this message Unabl...
# 5837    ​Hello Team,  can you please review the attach...
# 5374    ​ The CAT modeling that was complete is grayed...
# 6899    Good afternoon team, Per the attached, is ther...
# 4151    I get this error when I go into D&B Toolkit.  ...
# 4659    ​Jeff had a question about a 2018 emod and why...
# 2427     ​Error in Loss Analysis that the dates are wrong
# 4235    ​"Technical rating issue for CF/GL policy(ies)...
# Name: Clean Description, Length: 9313, dtype: object
